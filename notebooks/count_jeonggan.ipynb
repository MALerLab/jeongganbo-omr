# %%
# %cd ..
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/teo/userdata/git_libraries/jgb-omr

# %%
from data_utils import JeongganboReader
from pathlib import Path

# %%
piece_name_by_instrument = {}
piece_name_by_instrument['piri'] = ['여민락', '밑도드리', '웃도드리', '도드리 돌장', '영산회상 상령산', '영산회상 중령산', '영산회상 세령산', '영산회상 가락덜이', '영산회상 상현도드리',
                                    '영산회상 하현도드리', '영산회상 염불도드리', '영산회상 타령', '영산회상 군악', '천년만세 계면가락도드리', '천년만세 양청도드리', '천년만세 우조가락도드리',
                                    '평조회상 상령산', '평조회상 중령산', '평조회상 세령산', '평조회상 가락덜이', '평조회상 상현도드리', '평조회상 염불도드리', '평조회상 타령',
                                    '평조회상 군악', '관악영산회상 상령산', '관악영산회상 중령산', '관악영산회상 세령산', '관악영산회상 가락덜이', '관악영산회상 상현도드리', '관악영산회상 염불도드리',
                                    '관악영산회상 타령', '관악영산회상 군악', '취타 취타', '취타 길군악', '취타 길타령', '취타 별우조타령', '취타 군악', '수제천', '동동', '자진한잎 경풍년 우조두거',
                                    '자진한잎 경풍년 변조두거', '자진한잎 염양춘', '자진한잎 수룡음 농', '자진한잎 수룡음 계락', '자진한잎 수룡음 편1',  '자진한잎 수룡음 편2',
                                    '우조 다스름', '남창우조 초수대엽', '남창우조 이수대엽', '남창우조 중거', '남창우조 평거', '남창우조 두거', '남창우조 삼수대엽', '남창우조 소용이',
                                    '남창우조 우롱', '남창우조 우락', '남창우조 언락', '남창우조 우편', '남창반우반계 반엽', '가곡 계면 다스름', '남창계면 초수대엽', '남창계면 이수대엽',
                                    '남창계면 중거', '남창계면 평거', '남창계면 두거', '남창계면 삼수대엽', '남창계면 소용이', '남창계면 언롱', '남창계면 평롱', '남창계면 계락',
                                    '남창반우반계 편락', '남창계면 편수대엽', '남창계면 언편', '남창계면 태평가', '여창우조 이수대엽', '여창우조 중거', '여창우조 평거', '여창우조 두거',
                                    '여창우조 우락', '여창반우반계 반엽', '여창계면 이수대엽', '여창계면 중거', '여창계면 평거', '여창계면 두거', '여창계면 평롱', '여창계면 계락', 
                                    '여창반우반계 환계락', '여창계면 편수대엽', '여창계면 태평가',
                                    '보허자', '독주곡 상령산', '독주곡 염양춘', '현악취타 취타', '현악취타 길군악', '현악취타 길타령', '현악취타 별우조타령', '현악취타 군악']

piece_name_by_instrument['daegeum'] = ['여민락', '밑도드리', '웃도드리', '도드리 돌장', '영산회상 상령산', '영산회상 중령산', '영산회상 세령산', '영산회상 가락덜이', '영산회상 상현도드리',
                                       '영산회상 하현도드리', '영산회상 염불도드리', '영산회상 타령', '영산회상 군악', '천년만세 계면가락도드리', '천년만세 양청도드리', '천년만세 우조가락도드리',
                                       '평조회상 상령산', '평조회상 중령산', '평조회상 세령산', '평조회상 가락덜이', '평조회상 상현도드리', '평조회상 염불도드리', '평조회상 타령',
                                       '평조회상 군악','관악영산회상 상령산', '관악영산회상 중령산', '관악영산회상 세령산', '관악영산회상 가락덜이', '관악영산회상 상현도드리', '관악영산회상 염불도드리',
                                       '관악영산회상 타령', '관악영산회상 군악', '취타 취타', '취타 길군악', '취타 길타령', '취타 별우조타령', '취타 군악','수제천', '동동', '자진한잎 경풍년 우조두거',
                                       '자진한잎 경풍년 변조두거', '자진한잎 염양춘', '자진한잎 수룡음 농', '자진한잎 수룡음 계락', '자진한잎 수룡음 편1',  '자진한잎 수룡음 편2',
                                       '우조 다스름', '남창우조 초수대엽', '남창우조 이수대엽', '남창우조 중거', '남창우조 평거', '남창우조 두거', '남창우조 삼수대엽', '남창우조 소용이',
                                       '남창우조 우롱', '남창우조 우락', '남창우조 언락', '남창우조 우편', '남창반우반계 반엽', '가곡 계면 다스름', '남창계면 초수대엽', '남창계면 이수대엽',
                                       '남창계면 중거', '남창계면 평거', '남창계면 두거', '남창계면 삼수대엽', '남창계면 소용이', '남창계면 언롱', '남창계면 평롱', '남창계면 계락',
                                       '남창반우반계 편락', '남창계면 편수대엽', '남창계면 언편', '남창계면 태평가', '여창우조 이수대엽', '여창우조 중거', '여창우조 평거', '여창우조 두거',
                                       '여창우조 우락', '여창반우반계 반엽', '여창계면 이수대엽', '여창계면 중거', '여창계면 평거', '여창계면 두거', '여창계면 평롱', '여창계면 계락', 
                                       '여창반우반계 환계락', '여창계면 편수대엽', '여창계면 태평가',
                                       '해령', '보허자', '독주곡 헌천수', '독주곡 상령산1', '독주곡 상령산2', '독주곡 청성자진한잎', 
                                       '현악취타 취타', '현악취타 길군악', '현악취타 길타령', '현악취타 별우조타령', '현악취타 군악']

piece_name_by_instrument['haegeum'] = ['여민락', 
                                      '밑도드리', '웃도드리', '도드리 돌장', 
                                      '영산회상 상령산', '영산회상 중령산', '영산회상 세령산', '영산회상 가락덜이', '영산회상 상현도드리', '영산회상 하현도드리', '영산회상 염불도드리', '영산회상 타령', '영산회상 군악', '천년만세 계면가락도드리', '천년만세 양청도드리', '천년만세 우조가락도드리',
                                      '평조회상 상령산', '평조회상 중령산', '평조회상 세령산', '평조회상 가락덜이', '평조회상 상현도드리', '평조회상 염불도드리', '평조회상 타령', '평조회상 군악',
                                      '관악영산회상 상령산', '관악영산회상 중령산', '관악영산회상 세령산', '관악영산회상 가락덜이', '관악영산회상 상현도드리', '관악영산회상 염불도드리', '관악영산회상 타령', '관악영산회상 군악', 
                                      '취타 취타', '취타 길군악', '취타 길타령', '취타 별우조타령', '취타 군악',
                                      '수제천', '동동',
                                      '자진한잎 경풍년 우조두거','자진한잎 경풍년 변조두거', '자진한잎 염양춘', '자진한잎 수룡음 농', '자진한잎 수룡음 계락', '자진한잎 수룡음 편1',  '자진한잎 수룡음 편2',
                                      '우조 다스름', '남창우조 초수대엽', '남창우조 이수대엽', '남창우조 중거', '남창우조 평거', '남창우조 두거', '남창우조 삼수대엽', '남창우조 소용이',
                                      '남창우조 우롱', '남창우조 우락', '남창우조 언락', '남창우조 우편', '남창반우반계 반엽', '가곡 계면 다스름', '남창계면 초수대엽', '남창계면 이수대엽',
                                      '남창계면 중거', '남창계면 평거', '남창계면 두거', '남창계면 삼수대엽', '남창계면 소용이', '남창계면 언롱', '남창계면 평롱', '남창계면 계락',
                                      '남창반우반계 편락', '남창계면 편수대엽', '남창계면 언편', '남창계면 태평가', '여창우조 이수대엽', '여창우조 중거', '여창우조 평거', '여창우조 두거',
                                      '여창우조 우락', '여창반우반계 반엽', '여창계면 이수대엽', '여창계면 중거', '여창계면 평거', '여창계면 두거', '여창계면 평롱', '여창계면 계락', 
                                      '여창반우반계 환계락', '여창계면 편수대엽', '여창계면 태평가',
                                      '보허자',
                                      '현악취타 취타', '현악취타 길군악', '현악취타 길타령', '현악취타 별우조타령', '현악취타 군악']

piece_name_by_instrument['ajaeng'] = ['여민락', 
                                      '밑도드리', #'웃도드리', '도드리 돌장', 
                                      # '영산회상 상령산', '영산회상 중령산', '영산회상 세령산', '영산회상 가락덜이', '영산회상 상현도드리', '영산회상 하현도드리', '영산회상 염불도드리', '영산회상 타령', '영산회상 군악', '천년만세 계면가락도드리', '천년만세 양청도드리', '천년만세 우조가락도드리',
                                      '평조회상 상령산', '평조회상 중령산', '평조회상 세령산', '평조회상 가락덜이', '평조회상 상현도드리', '평조회상 염불도드리', '평조회상 타령', '평조회상 군악',
                                      '관악영산회상 상령산', '관악영산회상 중령산', '관악영산회상 세령산', '관악영산회상 가락덜이', '관악영산회상 상현도드리', '관악영산회상 염불도드리', '관악영산회상 타령', '관악영산회상 군악', 
                                      '취타 취타', '취타 길군악', '취타 길타령', '취타 별우조타령', '취타 군악',
                                      '수제천', '동동',
                                      '자진한잎 경풍년 우조두거','자진한잎 경풍년 변조두거', '자진한잎 염양춘', '자진한잎 수룡음 농', '자진한잎 수룡음 계락', '자진한잎 수룡음 편1',  '자진한잎 수룡음 편2',
                                      # '우조 다스름', '남창우조 초수대엽', '남창우조 이수대엽', '남창우조 중거', '남창우조 평거', '남창우조 두거', '남창우조 삼수대엽', '남창우조 소용이',
                                      # '남창우조 우롱', '남창우조 우락', '남창우조 언락', '남창우조 우편', '남창반우반계 반엽', '가곡 계면 다스름', '남창계면 초수대엽', '남창계면 이수대엽',
                                      # '남창계면 중거', '남창계면 평거', '남창계면 두거', '남창계면 삼수대엽', '남창계면 소용이', '남창계면 언롱', '남창계면 평롱', '남창계면 계락',
                                      # '남창반우반계 편락', '남창계면 편수대엽', '남창계면 언편', '남창계면 태평가', '여창우조 이수대엽', '여창우조 중거', '여창우조 평거', '여창우조 두거',
                                      # '여창우조 우락', '여창반우반계 반엽', '여창계면 이수대엽', '여창계면 중거', '여창계면 평거', '여창계면 두거', '여창계면 평롱', '여창계면 계락', 
                                      # '여창반우반계 환계락', '여창계면 편수대엽', '여창계면 태평가',
                                      '보허자',
                                      # '현악취타 취타', '현악취타 길군악', '현악취타 길타령', '현악취타 별우조타령', '현악취타 군악'
                                      ]


piece_name_by_instrument['gayageum'] = ['여민락', 
                                        '밑도드리', '웃도드리', '도드리 돌장', 
                                        '영산회상 상령산', '영산회상 중령산', '영산회상 세령산', '영산회상 가락덜이', '영산회상 상현도드리', '영산회상 하현도드리', '영산회상 염불도드리', '영산회상 타령', '영산회상 군악', '천년만세 계면가락도드리', '천년만세 양청도드리', '천년만세 우조가락도드리',
                                        '평조회상 상령산', '평조회상 중령산', '평조회상 세령산', '평조회상 가락덜이', '평조회상 상현도드리', '평조회상 염불도드리', '평조회상 타령', '평조회상 군악',
                                        # '관악영산회상 상령산', '관악영산회상 중령산', '관악영산회상 세령산', '관악영산회상 가락덜이', '관악영산회상 상현도드리', '관악영산회상 염불도드리', '관악영산회상 타령', '관악영산회상 군악', 
                                        '취타 취타', '현악취타 수요남극지곡', # '취타 길군악', '취타 길타령', '취타 별우조타령', '취타 군악',
                                        # '수제천', '동동',
                                        '보허사',
                                        '우조 다스름', '남창우조 초수대엽', '남창우조 이수대엽', '남창우조 중거', '남창우조 평거', '남창우조 두거', '남창우조 삼수대엽', '남창우조 소용이',
                                        '남창우조 우롱', '남창우조 우락', '남창우조 언락', '남창우조 우편', '남창반우반계 반엽', '가곡 계면 다스름', '남창계면 초수대엽', '남창계면 이수대엽',
                                        '남창계면 중거', '남창계면 평거', '남창계면 두거', '남창계면 삼수대엽', '남창계면 소용이', '남창계면 언롱', '남창계면 평롱', '남창계면 계락',
                                        '남창반우반계 편락', '남창계면 편수대엽', '남창계면 언편', '남창계면 태평가', '여창우조 이수대엽', '여창우조 중거', '여창우조 평거', '여창우조 두거',
                                        '여창우조 우락', '여창반우반계 반엽', '여창계면 이수대엽', '여창계면 중거', '여창계면 평거', '여창계면 두거', '여창계면 평롱', '여창계면 계락', 
                                        '여창반우반계 환계락', '여창계면 편수대엽', '여창계면 태평가',
                                        '자진한잎 경풍년 우조두거','자진한잎 경풍년 변조두거', '자진한잎 염양춘', '자진한잎 수룡음 농', '자진한잎 수룡음 계락', '자진한잎 수룡음 편1',  '자진한잎 수룡음 편2',
                                        '현악취타 취타', '현악취타 길군악', '현악취타 길타령', '현악취타 별우조타령', '현악취타 군악']

piece_name_by_instrument['geomungo'] = ['여민락', 
                                        '밑도드리', '웃도드리', '도드리 돌장', 
                                        '영산회상 상령산', '영산회상 중령산', '영산회상 세령산', '영산회상 가락덜이', '영산회상 상현도드리', '영산회상 하현도드리', '영산회상 염불도드리', '영산회상 타령', '영산회상 군악', 
                                        '영산회상 하현도드리 해탄가락', '영산회상 타령 해탄가락', '영산회상 군악 해탄가락',
                                        '천년만세 계면가락도드리', '천년만세 양청도드리', '천년만세 우조가락도드리', '천년만세 계면가락도드리 해탄가락',
                                        '평조회상 상령산', '평조회상 중령산', '평조회상 세령산', '평조회상 가락덜이', '평조회상 상현도드리', '평조회상 염불도드리', '평조회상 타령', '평조회상 군악',
                                        # '관악영산회상 상령산', '관악영산회상 중령산', '관악영산회상 세령산', '관악영산회상 가락덜이', '관악영산회상 상현도드리', '관악영산회상 염불도드리', '관악영산회상 타령', '관악영산회상 군악', 
                                        '취타 취타', '현악취타 수요남극지곡',
                                        # '수제천', '동동',
                                        '보허사',
                                        '우조 다스름', '남창우조 초수대엽', '남창우조 이수대엽', '남창우조 중거', '남창우조 평거', '남창우조 두거', '남창우조 삼수대엽', '남창우조 삼수대엽 고음부', '남창우조 삼수대엽 저음부', '남창우조 소용이',
                                        '남창우조 우롱', '남창우조 우락', '남창우조 언락', '남창우조 우편', '남창반우반계 반엽', '가곡 계면 다스름', '남창계면 초수대엽', '남창계면 이수대엽',
                                        '남창계면 중거', '남창계면 평거', '남창계면 두거', '남창계면 삼수대엽 고음부', '남창계면 삼수대엽 저음부', '남창계면 소용이', '남창계면 언롱', '남창계면 평롱1', '남창계면 평롱2', '남창계면 계락',
                                        '남창반우반계 편락', '남창계면 편수대엽', '남창계면 언편', '남창계면 태평가', '여창우조 이수대엽', '여창우조 중거', '여창우조 평거', '여창우조 두거',
                                        '여창우조 우락', '여창반우반계 반엽', '여창계면 이수대엽', '여창계면 중거1', '여창계면 중거2', '여창계면 평거', '여창계면 두거 고음부', '여창계면 두거 저음부', '여창계면 평롱', '여창계면 계락', 
                                        '여창반우반계 환계락', '여창계면 편수대엽', '여창계면 태평가',
                                        '자진한잎 경풍년 우조두거','자진한잎 경풍년 변조두거', '자진한잎 염양춘', '자진한잎 수룡음 농', '자진한잎 수룡음 계락', '자진한잎 수룡음 편1',  '자진한잎 수룡음 편2',
                                        '현악취타 취타', '현악취타 길군악', '현악취타 길타령', '현악취타 별우조타령', '현악취타 군악']

# %%
from constants import PIECE
piece_name_by_instrument = PIECE

# %%
png_dir = Path('jeongganbo-png/pngs/')
# png_fns = sorted(list(png_dir.glob('*.png')))

# instrument = 'haegeum'
instrument = 'piri'
reader = JeongganboReader()

instruments = ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum', 'ajaeng']
pieces_by_instrument = {}
page_starts_by_instrument = {}
page_starts_by_instrument['piri'] = 21
page_starts_by_instrument['daegeum'] = 16
page_starts_by_instrument['haegeum'] = 19
page_starts_by_instrument['geomungo'] = 17
page_starts_by_instrument['gayageum'] = 21
page_starts_by_instrument['ajaeng'] = 13

for instrument in instruments:
  print(f"Parsing {instrument}...")
  png_fns = sorted(list(png_dir.glob(f'{instrument}_pg-*.png')))
  pieces = reader.parse_multiple_pages(png_fns[page_starts_by_instrument[instrument]:])
  pieces_by_instrument[instrument] = pieces
# Out:
# Parsing piri...
# Processing jeongganbo-png/pngs/piri_pg-022.png
# No jeonggan detected at jeongganbo-png/pngs/piri_pg-022.png
# Processing jeongganbo-png/pngs/piri_pg-023.png
# No jeonggan detected at jeongganbo-png/pngs/piri_pg-023.png
# Processing jeongganbo-png/pngs/piri_pg-024.png
# Processing jeongganbo-png/pngs/piri_pg-025.png
# Processing jeongganbo-png/pngs/piri_pg-026.png
# Processing jeongganbo-png/pngs/piri_pg-027.png
# Processing jeongganbo-png/pngs/piri_pg-028.png
# Processing jeongganbo-png/pngs/piri_pg-029.png
# Processing jeongganbo-png/pngs/piri_pg-030.png
# Processing jeongganbo-png/pngs/piri_pg-031.png
# Processing jeongganbo-png/pngs/piri_pg-032.png
# Processing jeongganbo-png/pngs/piri_pg-033.png
# Processing jeongganbo-png/pngs/piri_pg-034.png
# Processing jeongganbo-png/pngs/piri_pg-035.png
# Processing jeongganbo-png/pngs/piri_pg-036.png
# Processing jeongganbo-png/pngs/piri_pg-037.png
# Processing jeongganbo-png/pngs/piri_pg-038.png
# ...

# %%
for instrument in instruments:
  print(f"{instrument}: Num Detected Piece: {len(pieces_by_instrument[instrument])}, Num Title Assigned: {len(piece_name_by_instrument[instrument])}")
# Out:
# piri: Num Detected Piece: 97, Num Title Assigned: 97
# haegeum: Num Detected Piece: 95, Num Title Assigned: 95
# daegeum: Num Detected Piece: 100, Num Title Assigned: 100
# geomungo: Num Detected Piece: 92, Num Title Assigned: 92
# gayageum: Num Detected Piece: 82, Num Title Assigned: 82
# ajaeng: Num Detected Piece: 33, Num Title Assigned: 33

# %%
from collections import defaultdict

piece_names = list(set([piece_name for instrument in instruments for piece_name in piece_name_by_instrument[instrument]]))

dict_by_piece_name = {}
for piece_name in piece_names:
  dict_by_piece_name[piece_name] = defaultdict(dict)

for inst in instruments:
  for title, piece in zip(piece_name_by_instrument[inst], pieces_by_instrument[inst]):
    dict_by_piece_name[title][inst] = piece

# %%
dict_by_piece_name['여창우조 우락']['piri'].pages[1].gaks
# Out:
# [Gak at Row 0 (1906, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (1726, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (1546, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (1366, 666) with 16 jeonggans. Avg height: 138.00, Start Beat: 0,
#  Gak at Row 0 (1186, 666) with 16 jeonggans. Avg height: 138.00, Start Beat: 0,
#  Gak at Row 0 (1006, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (826, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (646, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (466, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (286, 666) with 11 jeonggans. Avg height: 137.27, Start Beat: 0]

# %%
target_piece = "여창계면 평거"

dict_by_piece_name[target_piece]['piri'].pages, dict_by_piece_name[target_piece]['geomungo'].pages
# Out:
# ([Page with 130 jeonggan, Page with 123 jeonggan],
#  [Page with 133 jeonggan, Page with 123 jeonggan])

# %%
dict_by_piece_name[target_piece]['piri'].pages[0].gaks
# Out:
# [Jangdan Gak at Row 0 (1704, 666) with 16 jeonggans. Avg height: 138.56,
#  Gak at Row 0 (1523, 2192) with 5 jeonggans. Avg height: 138.20, Start Beat: 11,
#  Gak at Row 0 (1343, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (1163, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (982, 666) with 16 jeonggans. Avg height: 138.00, Start Beat: 0,
#  Gak at Row 0 (802, 1081) with 13 jeonggans. Avg height: 138.62, Start Beat: 3,
#  Gak at Row 0 (623, 666) with 16 jeonggans. Avg height: 138.00, Start Beat: 0,
#  Gak at Row 0 (442, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0,
#  Gak at Row 0 (262, 666) with 16 jeonggans. Avg height: 138.56, Start Beat: 0]

# %%
dict_by_piece_name[target_piece]['geomungo'].pages[0].gaks
# Out:
# [Jangdan Gak at Row 0 (1713, 669) with 16 jeonggans. Avg height: 138.50,
#  Gak at Row 0 (1532, 2194) with 5 jeonggans. Avg height: 138.20, Start Beat: 11,
#  Gak at Row 0 (1352, 669) with 16 jeonggans. Avg height: 138.50, Start Beat: 0,
#  Gak at Row 0 (1172, 669) with 16 jeonggans. Avg height: 138.50, Start Beat: 0,
#  Gak at Row 0 (992, 669) with 16 jeonggans. Avg height: 137.94, Start Beat: 0,
#  Gak at Row 0 (812, 669) with 16 jeonggans. Avg height: 138.50, Start Beat: 0,
#  Gak at Row 0 (632, 669) with 16 jeonggans. Avg height: 137.88, Start Beat: 0,
#  Gak at Row 0 (452, 669) with 16 jeonggans. Avg height: 138.50, Start Beat: 0,
#  Gak at Row 0 (272, 669) with 16 jeonggans. Avg height: 138.50, Start Beat: 0]

# %%
for piece in dict_by_piece_name:
  len_jeonggans = [len(dict_by_piece_name[piece][inst].jeonggans) for inst in dict_by_piece_name[piece]]
  inst_names = [inst for inst in dict_by_piece_name[piece]]
  if len(set(len_jeonggans)) != 1:
    print(f"{piece}: {len_jeonggans} / {inst_names}")
# Out:
# 여창계면 이수대엽: [240, 240, 240, 187, 240] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 여창계면 평롱: [259, 307, 259, 259, 307] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 여창반우반계 환계락: [264, 264, 264, 244, 264] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 가곡 계면 다스름: [176, 68, 176, 176, 284] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 취타 취타: [252, 252, 252, 234, 234, 252] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum', 'ajaeng']
# 도드리 돌장: [36, 36, 36, 48, 36] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 여창계면 계락: [234, 282, 240, 220, 282] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 남창계면 계락: [240, 240, 240, 288, 288] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 보허자: [580, 580, 580, 520] / ['piri', 'haegeum', 'daegeum', 'ajaeng']
# 우조 다스름: [188, 84, 188, 188, 292] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']

# %%
for piece in dict_by_piece_name:
  len_jeonggans = [len(dict_by_piece_name[piece][inst].jeonggans) for inst in dict_by_piece_name[piece]]
  inst_names = [inst for inst in dict_by_piece_name[piece]]
  if len(set(len_jeonggans)) == 1:
    print(f"{piece}: {len_jeonggans} / {inst_names}")
# Out:
# 영산회상 염불도드리: [306, 306, 306, 306, 306] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 여창우조 중거: [240, 240, 240, 240, 240] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 보허사: [1320, 1320] / ['geomungo', 'gayageum']
# 관악영산회상 상령산: [275, 275, 275, 275] / ['piri', 'haegeum', 'daegeum', 'ajaeng']
# 평조회상 가락덜이: [100, 100, 100, 100, 100, 100] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum', 'ajaeng']
# 영산회상 세령산: [140, 140, 140, 140, 140] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 독주곡 헌천수: [72] / ['daegeum']
# 웃도드리: [432, 432, 432, 432, 432] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum']
# 수제천: [387, 387, 387, 387] / ['piri', 'haegeum', 'daegeum', 'ajaeng']
# 자진한잎 경풍년 우조두거: [240, 240, 240, 240, 240, 240] / ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum', 'ajaeng']
# 관악영산회상 중령산: [360, 360, 360, 360] / ['piri', 'haegeum', 'daegeum', 'ajaeng']
# ...

# %%
dict_by_piece_name['여민락']['piri'].pages[-1].jeonggan_list
# Out:
# [Jeonggan at Gak 217, Daegang 0, Beat 0, Piece Beat 3140, img (1883, 489),
#  Jeonggan at Gak 217, Daegang 0, Beat 1, Piece Beat 3141, img (1883, 597),
#  Jeonggan at Gak 217, Daegang 0, Beat 2, Piece Beat 3142, img (1883, 706),
#  Jeonggan at Gak 217, Daegang 0, Beat 3, Piece Beat 3143, img (1883, 815),
#  Jeonggan at Gak 217, Daegang 0, Beat 4, Piece Beat 3144, img (1883, 924),
#  Jeonggan at Gak 217, Daegang 0, Beat 5, Piece Beat 3145, img (1883, 1033),
#  Jeonggan at Gak 217, Daegang 0, Beat 6, Piece Beat 3146, img (1883, 1142),
#  Jeonggan at Gak 217, Daegang 0, Beat 7, Piece Beat 3147, img (1883, 1251),
#  Jeonggan at Gak 217, Daegang 0, Beat 8, Piece Beat 3148, img (1883, 1360),
#  Jeonggan at Gak 217, Daegang 0, Beat 9, Piece Beat 3149, img (1883, 1469),
#  Jeonggan at Gak 218, Daegang 0, Beat 0, Piece Beat 3150, img (1703, 489),
#  Jeonggan at Gak 218, Daegang 0, Beat 1, Piece Beat 3151, img (1703, 597),
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(dict_by_piece_name['여창계면 태평가']['piri'].pages[2].img)

# %%
dict_by_piece_name['여창계면 태평가']['piri'].pages, dict_by_piece_name['여창계면 태평가']['geomungo'].pages
# Out:
# ([Page with 144 jeonggan, Page with 59 jeonggan, Page with 1 jeonggan],
#  [Page with 144 jeonggan, Page with 59 jeonggan])

# %%
inst = 'piri'
for piece, name in zip(pieces_by_instrument[inst], piece_name_by_instrument[inst]):
  print(piece, name)
# Out:
# Piece with 17 pages 여민락
# Piece with 4 pages 밑도드리
# Piece with 5 pages 웃도드리
# Piece with 1 pages 도드리 돌장
# Piece with 2 pages 영산회상 상령산
# Piece with 2 pages 영산회상 중령산
# Piece with 1 pages 영산회상 세령산
# Piece with 1 pages 영산회상 가락덜이
# Piece with 2 pages 영산회상 상현도드리
# Piece with 2 pages 영산회상 하현도드리
# Piece with 3 pages 영산회상 염불도드리
# Piece with 2 pages 영산회상 타령
# Piece with 3 pages 영산회상 군악
# Piece with 3 pages 천년만세 계면가락도드리
# Piece with 3 pages 천년만세 양청도드리
# Piece with 3 pages 천년만세 우조가락도드리
# Piece with 2 pages 평조회상 상령산
# Piece with 2 pages 평조회상 중령산
# Piece with 1 pages 평조회상 세령산
# Piece with 1 pages 평조회상 가락덜이
# Piece with 2 pages 평조회상 상현도드리
# Piece with 3 pages 평조회상 염불도드리
# Piece with 2 pages 평조회상 타령
# Piece with 3 pages 평조회상 군악
# Piece with 2 pages 관악영산회상 상령산
# Piece with 2 pages 관악영산회상 중령산
# Piece with 1 pages 관악영산회상 세령산
# Piece with 1 pages 관악영산회상 가락덜이
# Piece with 2 pages 관악영산회상 상현도드리
# Piece with 3 pages 관악영산회상 염불도드리
# Piece with 2 pages 관악영산회상 타령
# Piece with 3 pages 관악영산회상 군악
# ...

# %%
instrument = 'gayageum'
print(f"Parsing {instrument}...")
png_fns = sorted(list(png_dir.glob(f'{instrument}_pg-*.png')))
pieces = reader.parse_multiple_pages(png_fns[page_starts_by_instrument[instrument]:100])
pieces_by_instrument[instrument] = pieces
# Out:
# Parsing gayageum...
# Processing pngs/gayageum_pg-022.png
# Processing pngs/gayageum_pg-023.png
# Processing pngs/gayageum_pg-024.png
# Processing pngs/gayageum_pg-025.png
# Processing pngs/gayageum_pg-026.png
# Processing pngs/gayageum_pg-027.png
# Processing pngs/gayageum_pg-028.png
# Processing pngs/gayageum_pg-029.png
# Processing pngs/gayageum_pg-030.png
# Processing pngs/gayageum_pg-031.png
# ...
# Processing pngs/gayageum_pg-032.png
# Processing pngs/gayageum_pg-033.png
# Processing pngs/gayageum_pg-034.png
# Processing pngs/gayageum_pg-035.png
# Processing pngs/gayageum_pg-036.png
# Processing pngs/gayageum_pg-037.png
# Processing pngs/gayageum_pg-038.png
# Processing pngs/gayageum_pg-039.png
# No jeonggan detected at pngs/gayageum_pg-039.png
# Processing pngs/gayageum_pg-040.png
# No jeonggan detected at pngs/gayageum_pg-040.png
# Processing pngs/gayageum_pg-041.png
# No jeonggan detected at pngs/gayageum_pg-041.png
# Processing pngs/gayageum_pg-042.png
# ...

# %%
yeo = pieces_by_instrument['ajaeng'][3]
# yeo = pieces_by_instrument['gayageum'][2]
yeo.pages
# for page in geomun_yeo.pages:
#   print(len(page))
# page = yeo.pages[0]
# page.gaks
# Out:
# [Page with 180 jeonggan, Page with 188 jeonggan]

# %%
for i in range(10):

  for inst in instruments:
    print(f"{inst}_{i}: {len(pieces_by_instrument[inst][i].jeonggans)}")
    # print(len(pieces_by_instrument[inst][i].jeonggans))
# Out:
# piri_0: 3230
# haegeum_0: 3230
# daegeum_0: 3230
# geomungo_0: 3229
# gayageum_0: 3230
# ajaeng_0: 3230
# piri_1: 438
# haegeum_1: 438
# daegeum_1: 438
# geomungo_1: 438
# gayageum_1: 438
# ajaeng_1: 438
# piri_2: 474
# haegeum_2: 474
# daegeum_2: 474
# geomungo_2: 486
# gayageum_2: 474
# ajaeng_2: 360
# piri_3: 360
# haegeum_3: 360
# daegeum_3: 360
# geomungo_3: 360
# gayageum_3: 360
# ajaeng_3: 368
# piri_4: 368
# haegeum_4: 368
# daegeum_4: 368
# geomungo_4: 368
# gayageum_4: 368
# ajaeng_4: 150
# piri_5: 150
# haegeum_5: 150
# daegeum_5: 150
# geomungo_5: 150
# gayageum_5: 150
# ajaeng_5: 110
# piri_6: 110
# haegeum_6: 110
# daegeum_6: 110
# geomungo_6: 110
# gayageum_6: 110
# ajaeng_6: 244
# piri_7: 244
# haegeum_7: 244
# daegeum_7: 244
# geomungo_7: 220
# gayageum_7: 225
# ajaeng_7: 390
# piri_8: 156
# haegeum_8: 156
# daegeum_8: 156
# geomungo_8: 162
# gayageum_8: 162
# ajaeng_8: 298
# piri_9: 396
# haegeum_9: 396
# daegeum_9: 396
# geomungo_9: 312
# gayageum_9: 312
# ...

# %% [markdown]
# ## Detect title box

# %%
instruments
# Out:
# ['piri', 'haegeum', 'daegeum', 'geomungo', 'gayageum', 'ajaeng']

# %%
import cv2
reader = JeongganboReader()
title_png_dir = Path('title_pngs/')
title_png_dir.mkdir(exist_ok=True)

for instrument in instruments[4:]:
  num_titles = 0
  print(f"Parsing {instrument}...")
  png_fns = sorted(list(png_dir.glob(f'{instrument}_pg-*.png')))
  for fn in png_fns[page_starts_by_instrument[instrument]:]:
    img = reader.detect_title_box_from_img_path(str(fn))
    if img is not None:
      save_path = title_png_dir / (fn.stem + piece_name_by_instrument[instrument][num_titles] + '.png')
      # save image
      cv2.imwrite(str(save_path), img)
      num_titles += 1
# Out:
# Parsing gayageum...
# 1 Title box detected at pngs/gayageum_pg-022.png
# 1 Title box detected at pngs/gayageum_pg-042.png
# 1 Title box detected at pngs/gayageum_pg-046.png
# 1 Title box detected at pngs/gayageum_pg-050.png
# 2 Title box detected at pngs/gayageum_pg-054.png
# 1 Title box detected at pngs/gayageum_pg-056.png
# 1 Title box detected at pngs/gayageum_pg-058.png
# 1 Title box detected at pngs/gayageum_pg-059.png
# 1 Title box detected at pngs/gayageum_pg-060.png
# 1 Title box detected at pngs/gayageum_pg-062.png
# 1 Title box detected at pngs/gayageum_pg-063.png
# 1 Title box detected at pngs/gayageum_pg-065.png
# 1 Title box detected at pngs/gayageum_pg-067.png
# 2 Title box detected at pngs/gayageum_pg-074.png
# 1 Title box detected at pngs/gayageum_pg-076.png
# 1 Title box detected at pngs/gayageum_pg-078.png
# 2 Title box detected at pngs/gayageum_pg-084.png
# 1 Title box detected at pngs/gayageum_pg-086.png
# 1 Title box detected at pngs/gayageum_pg-088.png
# ...

# %%
img

# %%
fn.exists()
# Out:
# True
